# %%
# # 仅作为数据处理的测试版本，不作为最终版本
# import nibabel as nib
# import numpy as np
# from PIL import Image

# def nii_to_png(nii_file, output_dir):
#     """
#     将 .nii.gz 文件的每个切片转换为 .png 格式。
    
#     参数：
#     - nii_file: 输入的 .nii.gz 文件路径
#     - output_dir: 输出的保存目录
#     """
#     # 加载NIfTI文件
#     img = nib.load(nii_file)
    
#     # 获取图像数据，通常是一个3D数组（x, y, z）
#     img_data = img.get_fdata()
    
#     # 检查图像数据的维度
#     print(f"图像数据的维度: {img_data.shape}")
    
#     # 遍历每一个切片，通常是 Z 轴方向
#     for slice_idx in range(img_data.shape[2]):  # img_data.shape[2] 是 Z 轴的大小
#         # 选择指定的切片
#         slice_data = img_data[:, :, slice_idx]  # 选择 Z 轴上的切片
        
#         # 将切片数据归一化到 [0, 255] 范围
#         slice_data = np.uint8(np.interp(slice_data, (slice_data.min(), slice_data.max()), (0, 255)))
        
#         # 使用 Pillow 将图像保存为 .png 格式
#         img_pil = Image.fromarray(slice_data)
        
#         # 构建输出文件路径
#         output_file = f"{output_dir}/slice_{slice_idx}.png"
        
#         # 保存为 PNG 文件
#         img_pil.save(output_file)
#         print(f"图像已保存为 {output_file}")

# # 示例使用
# nii_file = 'E:/paperwork/trans_data/ACDC/training/patient001/patient001_frame01.nii.gz'  # 输入的 .nii.gz 文件路径
# output_dir = 'E:/paperwork/trans_data/ACDC/test_output'  # 输出目录，确保该目录已存在

# # 将 .nii.gz 转换为 .png
# nii_to_png(nii_file, output_dir)
# Out:
# 图像数据的维度: (216, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/test_output/slice_9.png

# %%
# 此版为数据处理的最终版本，作用是将ACDC数据集从官网中下载的格式，进行数据格式转换，只需要调整路径即可。
# 将nii.gz格式的数据直接转换成png的格式，对于每个切片都会进行转换，充实了整个数据，可以使数据使用率最大化。
# 其中 4d.nii.gz 格式的文件没有进行转换，直接进行了跳过。
# 生成后图像中，训练集有1902张，测试集有1076z张，其中少部分数据个人认为是脏数据，掩码不规范，即全白，可以进行手动删除。

import nibabel as nib
import numpy as np
from PIL import Image
import os

def nii_to_png(nii_file, output_dir, output_gt_dir):
    """
    将 .nii.gz 文件的每个切片转换为 .png 格式，并分别保存到不同的文件夹。
    
    参数：
    - nii_file: 输入的 .nii.gz 文件路径
    - output_dir: 不包含 '_gt' 的文件的输出保存目录
    - output_gt_dir: 包含 '_gt' 的文件的输出保存目录
    """
    # 加载NIfTI文件
    img = nib.load(nii_file)
    
    # 获取图像数据，通常是一个3D数组（x, y, z）
    img_data = img.get_fdata()
    
    # 检查图像数据的维度
    print(f"图像数据的维度: {img_data.shape}")
    
    # 遍历每一个切片，通常是 Z 轴方向
    for slice_idx in range(img_data.shape[2]):  # img_data.shape[2] 是 Z 轴的大小
        # 选择指定的切片
        slice_data = img_data[:, :, slice_idx]  # 选择 Z 轴上的切片
        
        # 检查切片数据的形状，确保是二维数组
        if slice_data.ndim != 2:
            print(f"切片 {slice_idx} 维度错误: {slice_data.shape}")
            continue  # 跳过这个错误的切片
        
        # 将切片数据归一化到 [0, 255] 范围
        slice_data = np.uint8(np.interp(slice_data, (slice_data.min(), slice_data.max()), (0, 255)))
        
        # 使用 Pillow 将图像保存为 .png 格式
        img_pil = Image.fromarray(slice_data)
        
        # 根据文件名判断输出路径
        if "_gt" in os.path.basename(nii_file):
            output_file = os.path.join(output_gt_dir, os.path.basename(nii_file).replace(".nii.gz", f"_slice_{slice_idx}.png"))
        else:
            output_file = os.path.join(output_dir, os.path.basename(nii_file).replace(".nii.gz", f"_slice_{slice_idx}.png"))
        
        # 保存为 PNG 文件
        img_pil.save(output_file)
        print(f"图像已保存为 {output_file}")

def process_patients(input_dir, output_dir, output_gt_dir):
    """
    遍历指定输入目录下的所有患者文件夹，将每个 .nii.gz 文件转换为 .png。
    
    参数：
    - input_dir: 包含患者文件夹的输入目录
    - output_dir: 不包含 '_gt' 的输出文件夹
    - output_gt_dir: 包含 '_gt' 的输出文件夹
    """
    # 遍历患者文件夹 (patient001, patient002, ..., patient100)
    for patient_num in range(1, 101):
        patient_folder = f"{input_dir}/patient{patient_num:03d}"
        
        # 如果患者文件夹存在，遍历其中的 .nii.gz 文件
        if os.path.exists(patient_folder):
            print(f"处理文件夹: {patient_folder}")
            
            # 遍历文件夹中的每个 .nii.gz 文件
            for filename in os.listdir(patient_folder):
                if filename.endswith(".nii.gz"):
                    nii_file = os.path.join(patient_folder, filename)
                    print(f"处理文件: {nii_file}")
                    
                    # 调用 nii_to_png 函数将 .nii.gz 文件转换为 .png
                    nii_to_png(nii_file, output_dir, output_gt_dir)

# 示例使用
input_dir = 'E:/paperwork/trans_data/ACDC/database/training'  # 输入目录，包含 patient001 到 patient100 文件夹
output_dir = 'E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train'  # 不包含 '_gt' 的输出目录
output_gt_dir = 'E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train'  # 包含 '_gt' 的输出目录

# 创建输出目录（如果不存在）
os.makedirs(output_dir, exist_ok=True)
os.makedirs(output_gt_dir, exist_ok=True)

# 处理所有患者文件夹
process_patients(input_dir, output_dir, output_gt_dir)
# Out:
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient001
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient001\patient001_4d.nii.gz
# 图像数据的维度: (216, 256, 10, 30)
# 切片 0 维度错误: (216, 256, 30)
# 切片 1 维度错误: (216, 256, 30)
# 切片 2 维度错误: (216, 256, 30)
# 切片 3 维度错误: (216, 256, 30)
# 切片 4 维度错误: (216, 256, 30)
# 切片 5 维度错误: (216, 256, 30)
# 切片 6 维度错误: (216, 256, 30)
# 切片 7 维度错误: (216, 256, 30)
# 切片 8 维度错误: (216, 256, 30)
# 切片 9 维度错误: (216, 256, 30)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient001\patient001_frame01.nii.gz
# 图像数据的维度: (216, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient001\patient001_frame01_gt.nii.gz
# 图像数据的维度: (216, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient001\patient001_frame12.nii.gz
# 图像数据的维度: (216, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient001_frame12_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient001\patient001_frame12_gt.nii.gz
# 图像数据的维度: (216, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient001_frame12_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient002
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient002\patient002_4d.nii.gz
# 图像数据的维度: (232, 256, 10, 30)
# 切片 0 维度错误: (232, 256, 30)
# 切片 1 维度错误: (232, 256, 30)
# 切片 2 维度错误: (232, 256, 30)
# 切片 3 维度错误: (232, 256, 30)
# 切片 4 维度错误: (232, 256, 30)
# 切片 5 维度错误: (232, 256, 30)
# 切片 6 维度错误: (232, 256, 30)
# 切片 7 维度错误: (232, 256, 30)
# 切片 8 维度错误: (232, 256, 30)
# 切片 9 维度错误: (232, 256, 30)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient002\patient002_frame01.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient002\patient002_frame01_gt.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient002\patient002_frame12.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient002_frame12_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient002\patient002_frame12_gt.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient002_frame12_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient003
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient003\patient003_4d.nii.gz
# 图像数据的维度: (256, 256, 10, 30)
# 切片 0 维度错误: (256, 256, 30)
# 切片 1 维度错误: (256, 256, 30)
# 切片 2 维度错误: (256, 256, 30)
# 切片 3 维度错误: (256, 256, 30)
# 切片 4 维度错误: (256, 256, 30)
# 切片 5 维度错误: (256, 256, 30)
# 切片 6 维度错误: (256, 256, 30)
# 切片 7 维度错误: (256, 256, 30)
# 切片 8 维度错误: (256, 256, 30)
# 切片 9 维度错误: (256, 256, 30)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient003\patient003_frame01.nii.gz
# 图像数据的维度: (256, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient003\patient003_frame01_gt.nii.gz
# 图像数据的维度: (256, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient003\patient003_frame15.nii.gz
# 图像数据的维度: (256, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient003_frame15_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient003\patient003_frame15_gt.nii.gz
# 图像数据的维度: (256, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient003_frame15_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient004
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient004\patient004_4d.nii.gz
# 图像数据的维度: (232, 256, 10, 28)
# 切片 0 维度错误: (232, 256, 28)
# 切片 1 维度错误: (232, 256, 28)
# 切片 2 维度错误: (232, 256, 28)
# 切片 3 维度错误: (232, 256, 28)
# 切片 4 维度错误: (232, 256, 28)
# 切片 5 维度错误: (232, 256, 28)
# 切片 6 维度错误: (232, 256, 28)
# 切片 7 维度错误: (232, 256, 28)
# 切片 8 维度错误: (232, 256, 28)
# 切片 9 维度错误: (232, 256, 28)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient004\patient004_frame01.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient004\patient004_frame01_gt.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient004\patient004_frame15.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient004_frame15_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient004\patient004_frame15_gt.nii.gz
# 图像数据的维度: (232, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient004_frame15_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient005
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient005\patient005_4d.nii.gz
# 图像数据的维度: (256, 216, 10, 30)
# 切片 0 维度错误: (256, 216, 30)
# 切片 1 维度错误: (256, 216, 30)
# 切片 2 维度错误: (256, 216, 30)
# 切片 3 维度错误: (256, 216, 30)
# 切片 4 维度错误: (256, 216, 30)
# 切片 5 维度错误: (256, 216, 30)
# 切片 6 维度错误: (256, 216, 30)
# 切片 7 维度错误: (256, 216, 30)
# 切片 8 维度错误: (256, 216, 30)
# 切片 9 维度错误: (256, 216, 30)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient005\patient005_frame01.nii.gz
# 图像数据的维度: (256, 216, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient005\patient005_frame01_gt.nii.gz
# 图像数据的维度: (256, 216, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient005\patient005_frame13.nii.gz
# 图像数据的维度: (256, 216, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient005_frame13_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient005\patient005_frame13_gt.nii.gz
# 图像数据的维度: (256, 216, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient005_frame13_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient006
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient006\patient006_4d.nii.gz
# 图像数据的维度: (232, 256, 11, 28)
# 切片 0 维度错误: (232, 256, 28)
# 切片 1 维度错误: (232, 256, 28)
# 切片 2 维度错误: (232, 256, 28)
# 切片 3 维度错误: (232, 256, 28)
# 切片 4 维度错误: (232, 256, 28)
# 切片 5 维度错误: (232, 256, 28)
# 切片 6 维度错误: (232, 256, 28)
# 切片 7 维度错误: (232, 256, 28)
# 切片 8 维度错误: (232, 256, 28)
# 切片 9 维度错误: (232, 256, 28)
# 切片 10 维度错误: (232, 256, 28)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient006\patient006_frame01.nii.gz
# 图像数据的维度: (232, 256, 11)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame01_slice_10.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient006\patient006_frame01_gt.nii.gz
# 图像数据的维度: (232, 256, 11)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame01_gt_slice_10.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient006\patient006_frame16.nii.gz
# 图像数据的维度: (232, 256, 11)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient006_frame16_slice_10.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient006\patient006_frame16_gt.nii.gz
# 图像数据的维度: (232, 256, 11)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient006_frame16_gt_slice_10.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient007
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient007\patient007_4d.nii.gz
# 图像数据的维度: (222, 224, 10, 16)
# 切片 0 维度错误: (222, 224, 16)
# 切片 1 维度错误: (222, 224, 16)
# 切片 2 维度错误: (222, 224, 16)
# 切片 3 维度错误: (222, 224, 16)
# 切片 4 维度错误: (222, 224, 16)
# 切片 5 维度错误: (222, 224, 16)
# 切片 6 维度错误: (222, 224, 16)
# 切片 7 维度错误: (222, 224, 16)
# 切片 8 维度错误: (222, 224, 16)
# 切片 9 维度错误: (222, 224, 16)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient007\patient007_frame01.nii.gz
# 图像数据的维度: (222, 224, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient007\patient007_frame01_gt.nii.gz
# 图像数据的维度: (222, 224, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient007\patient007_frame07.nii.gz
# 图像数据的维度: (222, 224, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient007_frame07_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient007\patient007_frame07_gt.nii.gz
# 图像数据的维度: (222, 224, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient007_frame07_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient008
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient008\patient008_4d.nii.gz
# 图像数据的维度: (200, 256, 10, 28)
# 切片 0 维度错误: (200, 256, 28)
# 切片 1 维度错误: (200, 256, 28)
# 切片 2 维度错误: (200, 256, 28)
# 切片 3 维度错误: (200, 256, 28)
# 切片 4 维度错误: (200, 256, 28)
# 切片 5 维度错误: (200, 256, 28)
# 切片 6 维度错误: (200, 256, 28)
# 切片 7 维度错误: (200, 256, 28)
# 切片 8 维度错误: (200, 256, 28)
# 切片 9 维度错误: (200, 256, 28)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient008\patient008_frame01.nii.gz
# 图像数据的维度: (200, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient008\patient008_frame01_gt.nii.gz
# 图像数据的维度: (200, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient008\patient008_frame13.nii.gz
# 图像数据的维度: (200, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient008_frame13_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient008\patient008_frame13_gt.nii.gz
# 图像数据的维度: (200, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient008_frame13_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient009
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient009\patient009_4d.nii.gz
# 图像数据的维度: (208, 256, 10, 35)
# 切片 0 维度错误: (208, 256, 35)
# 切片 1 维度错误: (208, 256, 35)
# 切片 2 维度错误: (208, 256, 35)
# 切片 3 维度错误: (208, 256, 35)
# 切片 4 维度错误: (208, 256, 35)
# 切片 5 维度错误: (208, 256, 35)
# 切片 6 维度错误: (208, 256, 35)
# 切片 7 维度错误: (208, 256, 35)
# 切片 8 维度错误: (208, 256, 35)
# 切片 9 维度错误: (208, 256, 35)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient009\patient009_frame01.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient009\patient009_frame01_gt.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient009\patient009_frame13.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient009_frame13_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient009\patient009_frame13_gt.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient009_frame13_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient010
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient010\patient010_4d.nii.gz
# 图像数据的维度: (208, 256, 10, 28)
# 切片 0 维度错误: (208, 256, 28)
# 切片 1 维度错误: (208, 256, 28)
# 切片 2 维度错误: (208, 256, 28)
# 切片 3 维度错误: (208, 256, 28)
# 切片 4 维度错误: (208, 256, 28)
# 切片 5 维度错误: (208, 256, 28)
# 切片 6 维度错误: (208, 256, 28)
# 切片 7 维度错误: (208, 256, 28)
# 切片 8 维度错误: (208, 256, 28)
# 切片 9 维度错误: (208, 256, 28)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient010\patient010_frame01.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame01_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient010\patient010_frame01_gt.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame01_gt_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient010\patient010_frame13.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient010_frame13_slice_9.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient010\patient010_frame13_gt.nii.gz
# 图像数据的维度: (208, 256, 10)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient010_frame13_gt_slice_9.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient011
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient011\patient011_4d.nii.gz
# 图像数据的维度: (216, 256, 9, 15)
# 切片 0 维度错误: (216, 256, 15)
# 切片 1 维度错误: (216, 256, 15)
# 切片 2 维度错误: (216, 256, 15)
# 切片 3 维度错误: (216, 256, 15)
# 切片 4 维度错误: (216, 256, 15)
# 切片 5 维度错误: (216, 256, 15)
# 切片 6 维度错误: (216, 256, 15)
# 切片 7 维度错误: (216, 256, 15)
# 切片 8 维度错误: (216, 256, 15)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient011\patient011_frame01.nii.gz
# 图像数据的维度: (216, 256, 9)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient011_frame01_slice_8.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient011\patient011_frame01_gt.nii.gz
# 图像数据的维度: (216, 256, 9)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient011_frame01_gt_slice_0.png
# ...
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient097\patient097_frame11.nii.gz
# 图像数据的维度: (216, 256, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient097_frame11_slice_7.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient097\patient097_frame11_gt.nii.gz
# 图像数据的维度: (216, 256, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient097_frame11_gt_slice_7.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient098
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient098\patient098_4d.nii.gz
# 图像数据的维度: (216, 256, 7, 22)
# 切片 0 维度错误: (216, 256, 22)
# 切片 1 维度错误: (216, 256, 22)
# 切片 2 维度错误: (216, 256, 22)
# 切片 3 维度错误: (216, 256, 22)
# 切片 4 维度错误: (216, 256, 22)
# 切片 5 维度错误: (216, 256, 22)
# 切片 6 维度错误: (216, 256, 22)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient098\patient098_frame01.nii.gz
# 图像数据的维度: (216, 256, 7)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame01_slice_6.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient098\patient098_frame01_gt.nii.gz
# 图像数据的维度: (216, 256, 7)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame01_gt_slice_6.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient098\patient098_frame09.nii.gz
# 图像数据的维度: (216, 256, 7)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient098_frame09_slice_6.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient098\patient098_frame09_gt.nii.gz
# 图像数据的维度: (216, 256, 7)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient098_frame09_gt_slice_6.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient099
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient099\patient099_4d.nii.gz
# 图像数据的维度: (154, 224, 16, 19)
# 切片 0 维度错误: (154, 224, 19)
# 切片 1 维度错误: (154, 224, 19)
# 切片 2 维度错误: (154, 224, 19)
# 切片 3 维度错误: (154, 224, 19)
# 切片 4 维度错误: (154, 224, 19)
# 切片 5 维度错误: (154, 224, 19)
# 切片 6 维度错误: (154, 224, 19)
# 切片 7 维度错误: (154, 224, 19)
# 切片 8 维度错误: (154, 224, 19)
# 切片 9 维度错误: (154, 224, 19)
# 切片 10 维度错误: (154, 224, 19)
# 切片 11 维度错误: (154, 224, 19)
# 切片 12 维度错误: (154, 224, 19)
# 切片 13 维度错误: (154, 224, 19)
# 切片 14 维度错误: (154, 224, 19)
# 切片 15 维度错误: (154, 224, 19)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient099\patient099_frame01.nii.gz
# 图像数据的维度: (154, 224, 16)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_10.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_11.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_12.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_13.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_14.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame01_slice_15.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient099\patient099_frame01_gt.nii.gz
# 图像数据的维度: (154, 224, 16)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_10.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_11.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_12.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_13.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_14.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame01_gt_slice_15.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient099\patient099_frame09.nii.gz
# 图像数据的维度: (154, 224, 16)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_10.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_11.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_12.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_13.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_14.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient099_frame09_slice_15.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient099\patient099_frame09_gt.nii.gz
# 图像数据的维度: (154, 224, 16)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_7.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_8.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_9.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_10.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_11.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_12.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_13.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_14.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient099_frame09_gt_slice_15.png
# 处理文件夹: E:/paperwork/trans_data/ACDC/database/training/patient100
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient100\patient100_4d.nii.gz
# 图像数据的维度: (216, 304, 8, 34)
# 切片 0 维度错误: (216, 304, 34)
# 切片 1 维度错误: (216, 304, 34)
# 切片 2 维度错误: (216, 304, 34)
# 切片 3 维度错误: (216, 304, 34)
# 切片 4 维度错误: (216, 304, 34)
# 切片 5 维度错误: (216, 304, 34)
# 切片 6 维度错误: (216, 304, 34)
# 切片 7 维度错误: (216, 304, 34)
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient100\patient100_frame01.nii.gz
# 图像数据的维度: (216, 304, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame01_slice_7.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient100\patient100_frame01_gt.nii.gz
# 图像数据的维度: (216, 304, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame01_gt_slice_7.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient100\patient100_frame13.nii.gz
# 图像数据的维度: (216, 304, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/img_dir/train\patient100_frame13_slice_7.png
# 处理文件: E:/paperwork/trans_data/ACDC/database/training/patient100\patient100_frame13_gt.nii.gz
# 图像数据的维度: (216, 304, 8)
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_0.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_1.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_2.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_3.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_4.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_5.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_6.png
# 图像已保存为 E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train\patient100_frame13_gt_slice_7.png

# %% [markdown]
# ## 此部分代码仅用于测试，与数据集格式转换无关

# %%
import os

import cv2
import numpy as np
from PIL import Image
from tqdm import tqdm

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
label_path = 'E:/paperwork/trans_data/ACDC/ACDC_move/ann_dir/train/patient001_frame01_gt_slice_0.png'
label = cv2.imread(label_path)
label.shape
# Out:
# (216, 256, 3)

# %%
np.unique(label)
# Out:
# array([255], dtype=uint8)
